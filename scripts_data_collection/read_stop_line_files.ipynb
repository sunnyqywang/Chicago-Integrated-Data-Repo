# %%
import geopandas as gpd
import fiona
# Out:
# /usr/local/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
bus_stops = gpd.read_file('./data_chicago/cta/CTA_BusStops.kml', driver = 'KML')
bus_routes = gpd.read_file('./data_chicago/cta/CTA_BusRoutes.kml', driver = 'KML')
rail_stops = gpd.read_file('./data_chicago/cta/CTA_RailStations.kml', driver = 'KML')
rail_routes = gpd.read_file('./data_chicago/cta/CTA_RailLines.kml', driver = 'KML')
metra_stops = gpd.read_file('./data_chicago/cta/Metra_Stations/MetraStations.shp')
metra_routes = gpd.read_file('./data_chicago/cta/Metra_Lines/MetraLinesshp.shp')
# Out:
# /usr/local/lib/python3.7/site-packages/geopandas/geodataframe.py:577: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   for feature in features_lst:

# %%
bus_stops.plot(markersize=.3)

# %%
rail_routes.plot()

# %%
metra_routes.plot()

# %%
metra_routes.head()
# Out:
#      ASSET_ID                LINES  \
# 0  21200078.0             Electric
# 1  21200075.0   Electric, S. Shore
# 2  21200001.0   Electric, S. Shore
# 3  21200212.0    UP-N, UP-NW, UP-W
# 4  21200211.0  Milw-N, Milw-W, NCS
#
#                                           DESCRIPTIO EDIT_INIT   EDIT_DATE  \
# 0                   18th St. (2.2) to 19th St. Merge        hm  1995-08-02
# 1  19th St. Merge (no junction) to McCormick Plac...        hm  1995-08-02
# 2                  11th Pl. Divide to 19th St. Merge       aef  2001-03-08
# 3            Ogilvie Station to Clinton St. Junction        hm  1995-08-02
# 4  Union Station (North) to Western Ave. Interloc...       aef  2001-11-05
#
#                                             geometry
# 0  LINESTRING (1179110.460 1891558.940, 1179246.1...
# 1  LINESTRING (1179304.490 1891141.030, 1179335.0...
# 2  LINESTRING (1178673.070 1893747.260, 1178765.7...
# 3  LINESTRING (1172450.020 1903128.830, 1172503.0...
# ...
